# %% [markdown]
# # DS4200 Homework 2
#
# Due: Friday Feb 7th @ 11:59 PM EST
#
# ### Submission Instructions
# Submit this `ipynb` file included with the coding results as well as the picture in the last question to Gradescope (this can also be done via the assignment on Canvas).  To ensure that your submitted files represent your latest code, make sure to give a fresh `Kernel > Restart & Run All` just before uploading the files to gradescope.
#
# ### Tips for success
# - Start early
# - Make use of Piazza
# - Make use of Office hour
# - Remember to use cells and headings to make the notebook easy to read (if a grader cannot find the answer to a problem, you will receive no points for it)
# - Under no circumstances may one student view or share their ungraded homework or quiz with another student [(see also)](http://www.northeastern.edu/osccr/academic-integrity), though you are welcome to **talk about** (not show each other) the problems.

# %% [markdown]
# ### Part 1 - Encodings (25 points)
#
# Navigate to [datavizproject](https://datavizproject.com/) and take some time to freely browse the website and explore. After browsing, find a visual encoding on the webpage that is new to you (i.e. one you have never seen before).
#
# ##### Quesiton 1 (5 pts)
# Put in this section a screenshot and hyperlink to the visual encoding that is new to you.

# %% [markdown]
# ![Screenshot 2025-02-06 at 9.50.10 PM.png](attachment:81e7e28a-7362-46dc-b6f8-7633ca4c7df7.png)

# %% [markdown]
# https://datavizproject.com/data-type/pictorial-fraction-chart/

# %% [markdown]
# ##### Question 2 (5 pts)
#
# Add a short paragraph explaining what you like and do not like about the new-to-you visual encoding you selected.

# %% [markdown]
# This is a unique and intuitive method to display data related to proportions, as it creates an immediate connection between the visual and the concept of a "whole." I like how the figure makes it easier for viewers to quickly understand the data—it's simple and direct. However, one downside is that it may not scale well with more complex data sets or where precise quantitative information is needed. In such cases, the human figure might not provide the necessary clarity or detail compared to more traditional graphs or charts. For audiences who prefer more traditional data presentations, this style might come off as overly simplistic or too abstract for accurate analysis in some contexts.

# %% [markdown]
# Take a look at the toolbar at the top of the webpage. Note how visualizations are organized (categorized) in multiple ways to help the user identify a visual encoding depending on whether they care about data type, composition, or task.
#
# ##### Question 3 (5 pts)
#
# What does “Input” mean? How are the visualizations categorized in this scheme? How does (if at all) this map to the language in our readings?

# %% [markdown]
# Input refers to the type of data that a visualization is designed to work with. This is a helpful way to categorize visualizations because different types of data sets require different types of charts or graphs to represent them effectively. The website categorizes visualizations based on the input type. For example, if you have time-based data, the site will show you visualizations designed for that kind of input (line charts or time series charts). In the lecture, we discussed that data visualization is fundamentally about selecting the right visual encoding for the data we are working with. The website’s categorization system maps directly to this by showing how the choice of visualization depends on the type of data. Both the website and the readings emphasize that choosing the right visual encoding is extremely important for effective communication and analysis of data.

# %% [markdown]
# ##### Question 4 (5 pts)
#
# What does “Shape” mean? How are the visualizations categorized in this scheme? How does (if at all) this map to the language in our readings?

# %% [markdown]
# Shape refers to the visual forms (like points, lines, or bars) used to represent data. Visualizations are categorized by the specific shapes or marks they use, such as points for scatter plots, lines for trends, or bars for comparisons. This categorization helps users select the right shape to effectively convey their data. In the readings, this aligns with the concept of "mark types", which are key visual elements (like points, lines, or bars) that represent data in visualizations. For example, categorical data is often best represented with bars, while network data benefits from node-link diagrams.

# %% [markdown]
# ##### Question 5 (5 pts)
#
# What does “Function” mean? How are the visualizations categorized in this scheme? How does (if at all) this map to the language in our readings?

# %% [markdown]
# Function refers to the specific purpose a visualization serves, such as identifying trends, making comparisons, or exploring relationships. Visualizations are categorized based on function into groups like comparison (bar charts), trend analysis (line charts), distribution (histograms), relationships (scatter plots), and part-to-whole representation (pie charts). This classification aligns with the nested model of data visualization which was discussed in the lecture, which emphasizes different levels of abstraction from raw data to final visual encoding. Function categorizes to the task needed to achieved, where visual choices depend on user interactions, such as recognizing patterns or comparing values. The lecture also discusses data types (categorical vs. continuous), datasets, and field data, which influence the selection of appropriate visualization types. For example, categorical data is best suited for comparison-based visualizations, while continuous data for trend or distribution-based visualizations.

# %% [markdown]
# ### Part 2 - Xenographics (15 points)
#
# Watch the following talk about the Xenographics project by Maarten Lambrechts from the OpenVis Conf (2018): [https://www.youtube.com/watch?v=fp-WNqaQG0s](https://www.youtube.com/watch?v=fp-WNqaQG0s)
#
# Next, explore the online collection: https://xeno.graphics/.

# %% [markdown]
# Then, write a 1-2 paragraph response (minimum 200 words) which addresses the following questions:
#
# - What is the Xenographics project, and what is its goal?
# - How are the visualizations categorized and organized on the project website?
# - What was the most interesting or surprising thing you learned by watching the talk and exploring the website?
# - Provide a link and short description to your favorite visualization on the website.
#
# Your 1–2 paragraphs evidence a critical and thoughtful effort and answer the posed questions. Your writing shows a high degree of attention to logic and reasoning of points, is written in a clear manner, and words are chosen to precisely express the intended meaning and support reader comprehension. There are few English spelling or grammar mistakes.

# %% [markdown]
# The Xenographics project, created by Maarten Lambrechts, is a collection of unusual and less common data visualizations that go beyond standard charts like bar graphs and line charts. Its goal is to showcase and analyze these unique visual forms, encouraging designers and analysts to consider alternative ways to present data. The project’s website organizes these visualizations by their structure and purpose, such as circular, grid-based, or network-based designs. Each example includes a brief description, an image, and a link to its original source, making it easy to explore real-world uses.
#
# One of the most interesting takeaways from Lambrechts’ talk and the website is that many of these unusual charts have practical purposes. At first, some may seem complicated or unnecessary, but they often provide insights that standard charts cannot. For example, when displaying relationships, hierarchies, or repeating patterns, a non-traditional visualization can highlight key trends more effectively. My favorite visualization from the collection is the Horizon chart, which condenses multiple time-series graphs into a color-coded format. It displays quantitative information over a series of time. This makes it easier to compare trends without taking up too much space, which is useful for financial or environmental data.

# %% [markdown]
# ### Part 3 - Basic data analysis with Altair (40 points)
#
# We are going to use the same Weather data from Homework 1 but use Altair to create the data visualziation.
#
# ##### Question 1 (10 points)
#
# Recreate the figure in Part 3 Question 2 in Homework 1 with Altair. Include necessary title and labels. Here is the question again:
#
#     Generate a data visualization to show the relationship between max temperature and weather type.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import altair as alt
from vega_datasets import data

weather = data.seattle_weather()
weather.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
chart = alt.Chart(weather).mark_point().encode(
    x='temp_max:Q',  
    y='weather:N',  
    color='weather:N',  
    tooltip=['temp_max', 'weather']  
).properties(
    title='Relationship Between Max Temperature and Weather Type'  
)

chart.show()
# Out:
# alt.Chart(...)

# %% [markdown]
# ##### Question 2 (10 points)
#
# Recreate the figure in Part 3 Question 3 in Homework 1 with Altair. Include necessary title and labels. Here is the question again:
#
#     Generate a data visualization to show the relationship between max temperature and min temperature, and then show different color for differnet weather type.

# %%
chart = alt.Chart(weather).mark_point().encode(x='temp_max:Q', y='temp_min:Q', color='weather:N',  tooltip=['temp_max', 'temp_min', 'weather']).properties(title='Relationship Between Max Temperature and Min Temperature')

chart.show()
# Out:
# alt.Chart(...)

# %% [markdown]
# ##### Question 3 (10 points)
#
# Create a facet figure in Altair with 2 row and 3 columns. For each panel in the facet figure, it shows a scatter plot between the max and min temperature for one type of weather. Use the wind speed to color the points. Also add interaction to show the max and min temperature and wind speed for each data point. Include necessary title and labels.

# %%
facet_chart = alt.Chart(weather).mark_point().encode(
    x='temp_max:Q',  
    y='temp_min:Q',  
    color='wind:Q',  
    tooltip=['temp_max', 'temp_min', 'wind']  
).facet(
    column='weather:N',  
    columns=3  
).properties(
    title='Scatter Plot of Max vs. Min Temperature by Weather Type' 
)

facet_chart.show()
# Out:
# alt.FacetChart(...)

# %% [markdown]
# ##### Question 4 (10 points)
#
# Create a compound figure with at least two types of marks. Show the trend of average temperature (the average of min and max temperature) in 4 years. Note, just use the `date` as X attribute, no need to aggragate for years and you will get a wide figure. Include necessary title and labels.

# %%
weather["avg_temp"] = (weather["temp_min"] + weather["temp_max"]) / 2

chart = alt.Chart(weather).encode(
    x=alt.X("date:T", title="Date") 
)

line = chart.mark_line(color="blue").encode(
    y=alt.Y("avg_temp:Q", title="Average Temperature (°C)")
)

points = chart.mark_point(color="purple").encode(
    y="avg_temp:Q"
)

compound_chart = (line + points).properties(
    title="Trend of Average Temperature Over 4 Years",
    width=800,
    height=400
)

compound_chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Part 4 - Colors (20 points)
#
# Please email the instructor if you have problems to complete the color-related homework.
#
# ##### Question 1 (5 points)
#
# Following is a density plot for the wind speed for all five types of weather. Is there any problems in the figure? Try to name at least two ways you can do to re-design the figure (change the mark/channel/encoding etc.)

# %% [markdown]
# <img src="https://i.ibb.co/QNfQ2tb/visualization.png" alt="visualization" border="0">

# %% [markdown]
# The density plot has some issues, such as overlapping areas that make it difficult to distinguish between different weather types. One solution would be to adjust the opacity of the colors to make the overlapping distributions clearer. Additionally, the color scheme could be made more accessible by using more contrasting colors or patterns for each weather type. Lastly, improving the placement of the legend and adding clearer axis labels could enhance the plot's overall readability.

# %% [markdown]
# ##### Question 2 （5 points）
#
# Go to [http://vrl.cs.brown.edu/color](http://vrl.cs.brown.edu/color) and select another color palette for the figure. Explain how to set the configuration to get the color palette. Take a screenshot of the color palette you have chosen on the website and then go to [https://www.color-blindness.com/coblis-color-blindness-simulator/](https://www.color-blindness.com/coblis-color-blindness-simulator/) and upload the screenshot. Discuss how one of the color-blind illness affects the figure.

# %% [markdown]
# Tritanopia alters color perception by making blues, greens, yellows, and reds harder to distinguish. In the tritanopia version, the bright purples and blues became muted and shift toward grayish or reddish tones, making them less distinct. Blues and greens, which were clearly separate in the original, now looked more similar, which could make differentiating categories in a chart more difficult. Additionally, the light pink and green shift toward more neutral tones.

# %% [markdown]
# ##### Question 3 (10 points)
#
# Based on what we have learned in the lecture, try to create an example for the color illusion. You can choose from:
# + Simultaneous Contrast: Colors look different depending on the surrounding colors (light and dark).
# + Gradient Illusion: how the gradient background affect the solid color in front of it.
# + Color Context Effects: The same color can appear lighter, darker, or even as a different hue depending on its background, eg: the border.
#
# Attach the picture of your design to the homework (You can zip the picture and .ipynb file when you submit it or submit the GitHub repo). You can choose any tool for your design, PPT, Canvas, Photoshop etc. Do not directly copy the lecture examples. Write a few sentence about your design. How you design it and which illusion you are addressing.

# %% [markdown]
# ![Screenshot 2025-02-07 at 2.48.35 PM.png](attachment:89f1cd0e-4116-43fa-b175-24d8fc3b9aff.png)

# %% [markdown]
# This image demonstrates the Gradient Illusion, where a solid-colored object appears to change color depending on the background gradient. The gray square in the center is actually the same shade throughout, but due to the shifting background from black to white, our perception makes it look darker in the lighter areas and lighter in the darker areas. I created this design by placing a neutral gray square over a radial gradient background that smoothly transitions from black to white. This was made using PowerPoint. This illusion highlights how our brain interprets colors based on surrounding contrasts, which is important in design and data visualization to avoid misleading visual interpretations.
